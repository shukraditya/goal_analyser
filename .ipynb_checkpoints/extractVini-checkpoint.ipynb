# %%
import requests
from bs4 import BeautifulSoup#not beautifulsoup, so stupid
import json
import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer import VerticalPitch

# %%
player_url = "https://understat.com/player/"
player = str(input("Please enter the player_id: "))
url = player_url+player
# Out:
# Please enter the player_id:  7008

# %%
url
# Out:
# 'https://understat.com/player/7008'

# %%
res = requests.get(url)

soup = BeautifulSoup(res.content,'html.parser')

scripts = soup.find_all('script')

# %%
groups = scripts[1].string
minmaxplayerstats = scripts[2].string
shots = scripts[3].string
matches = scripts[4].string

# %%
ind_start = shots.index("('")+2
ind_end = shots.index("')")

json_data = shots[ind_start:ind_end]
json_data = json_data.encode('utf8').decode('unicode_escape')

data = json.loads(json_data)

# %%
data #JSON
# Out:
# [{'id': '258765',
#   'minute': '82',
#   'result': 'Goal',
#   'X': '0.885',
#   'Y': '0.6880000305175781',
#   'xG': '0.051118601113557816',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10065',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Valladolid',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2018-11-03 15:15:00',
#   'player_assisted': 'Isco',
#   'lastAction': 'Pass'},
#  {'id': '259285',
#   'minute': '89',
#   'result': 'MissedShots',
#   'X': '0.7930000305175782',
#   'Y': '0.674000015258789',
#   'xG': '0.02699729986488819',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10084',
#   'h_team': 'Eibar',
#   'a_team': 'Real Madrid',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2018-11-24 12:00:00',
#   'player_assisted': 'Marcelo',
#   'lastAction': 'BallRecovery'},
#  {'id': '260090',
#   'minute': '86',
#   'result': 'BlockedShot',
#   'X': '0.924000015258789',
#   'Y': '0.27600000381469725',
#   'xG': '0.052585601806640625',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10116',
#   'h_team': 'Real Madrid',
#   'a_team': 'Rayo Vallecano',
#   'h_goals': '1',
#   'a_goals': '0',
#   'date': '2018-12-15 17:30:00',
#   'player_assisted': 'Lucas Vázquez',
#   'lastAction': 'Pass'},
#  {'id': '279985',
#   'minute': '14',
#   'result': 'SavedShot',
#   'X': '0.8930000305175781',
#   'Y': '0.6630000305175782',
#   'xG': '0.22689999639987946',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'LeftFoot',
#   'match_id': '10133',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Sociedad',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2019-01-06 17:30:00',
#   'player_assisted': 'Karim Benzema',
#   'lastAction': 'Pass'},
#  {'id': '279997',
#   'minute': '46',
#   'result': 'SavedShot',
#   'X': '0.9619999694824218',
#   'Y': '0.37099998474121093',
#   'xG': '0.08477749675512314',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'FromCorner',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10133',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Sociedad',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2019-01-06 17:30:00',
#   'player_assisted': None,
#   'lastAction': 'Rebound'},
#  {'id': '280002',
#   'minute': '50',
#   'result': 'MissedShots',
#   'X': '0.86',
#   'Y': '0.41700000762939454',
#   'xG': '0.08507339656352997',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10133',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Sociedad',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2019-01-06 17:30:00',
#   'player_assisted': 'Karim Benzema',
#   'lastAction': 'TakeOn'},
#  {'id': '280009',
#   'minute': '65',
#   'result': 'SavedShot',
#   'X': '0.915',
#   'Y': '0.639000015258789',
#   'xG': '0.04910380020737648',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10133',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Sociedad',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2019-01-06 17:30:00',
#   'player_assisted': 'Daniel Carvajal',
#   'lastAction': 'Cross'},
#  {'id': '280016',
#   'minute': '78',
#   'result': 'MissedShots',
#   'X': '0.8780000305175781',
#   'Y': '0.73',
#   'xG': '0.02079389989376068',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10133',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Sociedad',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2019-01-06 17:30:00',
#   'player_assisted': 'Daniel Carvajal',
#   'lastAction': 'Cross'},
#  {'id': '280021',
#   'minute': '91',
#   'result': 'MissedShots',
#   'X': '0.75',
#   'Y': '0.7469999694824219',
#   'xG': '0.007655330002307892',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10133',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Sociedad',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2019-01-06 17:30:00',
#   'player_assisted': 'Daniel Carvajal',
#   'lastAction': 'Chipped'},
#  {'id': '280264',
#   'minute': '20',
#   'result': 'SavedShot',
#   'X': '0.865999984741211',
#   'Y': '0.7090000152587891',
#   'xG': '0.04881640151143074',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10143',
#   'h_team': 'Real Betis',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2019-01-13 19:45:00',
#   'player_assisted': 'Sergio Reguilón',
#   'lastAction': 'Pass'},
#  {'id': '280267',
#   'minute': '29',
#   'result': 'SavedShot',
#   'X': '0.8730000305175781',
#   'Y': '0.4329999923706055',
#   'xG': '0.11152999848127365',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10143',
#   'h_team': 'Real Betis',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2019-01-13 19:45:00',
#   'player_assisted': 'Karim Benzema',
#   'lastAction': 'Pass'},
#  {'id': '280274',
#   'minute': '53',
#   'result': 'SavedShot',
#   'X': '0.9069999694824219',
#   'Y': '0.725999984741211',
#   'xG': '0.044650599360466',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10143',
#   'h_team': 'Real Betis',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2019-01-13 19:45:00',
#   'player_assisted': 'Cristo González',
#   'lastAction': 'Pass'},
#  {'id': '280336',
#   'minute': '5',
#   'result': 'SavedShot',
#   'X': '0.9059999847412109',
#   'Y': '0.3060000038146973',
#   'xG': '0.32671400904655457',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10150',
#   'h_team': 'Real Madrid',
#   'a_team': 'Sevilla',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2019-01-19 15:15:00',
#   'player_assisted': 'Karim Benzema',
#   'lastAction': 'Throughball'},
#  {'id': '280337',
#   'minute': '6',
#   'result': 'BlockedShot',
#   'X': '0.8830000305175781',
#   'Y': '0.36400001525878906',
#   'xG': '0.08242689818143845',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10150',
#   'h_team': 'Real Madrid',
#   'a_team': 'Sevilla',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2019-01-19 15:15:00',
#   'player_assisted': 'Daniel Carvajal',
#   'lastAction': 'Pass'},
#  {'id': '280344',
#   'minute': '46',
#   'result': 'SavedShot',
#   'X': '0.7440000152587891',
#   'Y': '0.6780000305175782',
#   'xG': '0.0178568996489048',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10150',
#   'h_team': 'Real Madrid',
#   'a_team': 'Sevilla',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2019-01-19 15:15:00',
#   'player_assisted': 'Dani Ceballos',
#   'lastAction': 'Pass'},
#  {'id': '280345',
#   'minute': '51',
#   'result': 'MissedShots',
#   'X': '0.9259999847412109',
#   'Y': '0.75',
#   'xG': '0.032503001391887665',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10150',
#   'h_team': 'Real Madrid',
#   'a_team': 'Sevilla',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2019-01-19 15:15:00',
#   'player_assisted': 'Luka Modric',
#   'lastAction': 'Pass'},
#  {'id': '280354',
#   'minute': '62',
#   'result': 'MissedShots',
#   'X': '0.825999984741211',
#   'Y': '0.534000015258789',
#   'xG': '0.07104729861021042',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10150',
#   'h_team': 'Real Madrid',
#   'a_team': 'Sevilla',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2019-01-19 15:15:00',
#   'player_assisted': 'Dani Ceballos',
#   'lastAction': 'Pass'},
#  {'id': '280720',
#   'minute': '2',
#   'result': 'SavedShot',
#   'X': '0.7959999847412109',
#   'Y': '0.674000015258789',
#   'xG': '0.02636829949915409',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10163',
#   'h_team': 'Espanyol',
#   'a_team': 'Real Madrid',
#   'h_goals': '2',
#   'a_goals': '4',
#   'date': '2019-01-27 19:45:00',
#   'player_assisted': 'Toni Kroos',
#   'lastAction': 'Pass'},
#  {'id': '280989',
#   'minute': '15',
#   'result': 'SavedShot',
#   'X': '0.8219999694824218',
#   'Y': '0.524000015258789',
#   'xG': '0.06488250195980072',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10172',
#   'h_team': 'Real Madrid',
#   'a_team': 'Alaves',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2019-02-03 19:45:00',
#   'player_assisted': None,
#   'lastAction': 'BallRecovery'},
#  {'id': '280992',
#   'minute': '28',
#   'result': 'BlockedShot',
#   'X': '0.8209999847412109',
#   'Y': '0.6680000305175782',
#   'xG': '0.03556869924068451',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10172',
#   'h_team': 'Real Madrid',
#   'a_team': 'Alaves',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2019-02-03 19:45:00',
#   'player_assisted': 'Dani Ceballos',
#   'lastAction': 'Pass'},
#  {'id': '281002',
#   'minute': '63',
#   'result': 'BlockedShot',
#   'X': '0.86',
#   'Y': '0.745999984741211',
#   'xG': '0.03548960015177727',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10172',
#   'h_team': 'Real Madrid',
#   'a_team': 'Alaves',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2019-02-03 19:45:00',
#   'player_assisted': 'Dani Ceballos',
#   'lastAction': 'Pass'},
#  {'id': '281004',
#   'minute': '68',
#   'result': 'BlockedShot',
#   'X': '0.8419999694824218',
#   'Y': '0.5609999847412109',
#   'xG': '0.08790399879217148',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10172',
#   'h_team': 'Real Madrid',
#   'a_team': 'Alaves',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2019-02-03 19:45:00',
#   'player_assisted': None,
#   'lastAction': 'Dispossessed'},
#  {'id': '281005',
#   'minute': '69',
#   'result': 'MissedShots',
#   'X': '0.8180000305175781',
#   'Y': '0.645',
#   'xG': '0.05825459957122803',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10172',
#   'h_team': 'Real Madrid',
#   'a_team': 'Alaves',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2019-02-03 19:45:00',
#   'player_assisted': 'Luka Modric',
#   'lastAction': 'Dispossessed'},
#  {'id': '281009',
#   'minute': '79',
#   'result': 'Goal',
#   'X': '0.9159999847412109',
#   'Y': '0.5979999923706054',
#   'xG': '0.42368099093437195',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10172',
#   'h_team': 'Real Madrid',
#   'a_team': 'Alaves',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2019-02-03 19:45:00',
#   'player_assisted': 'Marco Asensio',
#   'lastAction': 'Chipped'},
#  {'id': '281437',
#   'minute': '76',
#   'result': 'MissedShots',
#   'X': '0.86',
#   'Y': '0.6370000076293946',
#   'xG': '0.05770169943571091',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10189',
#   'h_team': 'Real Madrid',
#   'a_team': 'Girona',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2019-02-17 11:00:00',
#   'player_assisted': 'Karim Benzema',
#   'lastAction': 'Pass'},
#  {'id': '281438',
#   'minute': '79',
#   'result': 'MissedShots',
#   'X': '0.8090000152587891',
#   'Y': '0.639000015258789',
#   'xG': '0.037458401173353195',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10189',
#   'h_team': 'Real Madrid',
#   'a_team': 'Girona',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2019-02-17 11:00:00',
#   'player_assisted': 'Álvaro Odriozola',
#   'lastAction': 'Pass'},
#  {'id': '281742',
#   'minute': '30',
#   'result': 'SavedShot',
#   'X': '0.9390000152587891',
#   'Y': '0.27700000762939453',
#   'xG': '0.036386698484420776',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10199',
#   'h_team': 'Levante',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2019-02-24 19:45:00',
#   'player_assisted': 'Karim Benzema',
#   'lastAction': 'Pass'},
#  {'id': '281750',
#   'minute': '47',
#   'result': 'BlockedShot',
#   'X': '0.7659999847412109',
#   'Y': '0.6079999923706054',
#   'xG': '0.031607501208782196',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10199',
#   'h_team': 'Levante',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2019-02-24 19:45:00',
#   'player_assisted': 'Sergio Reguilón',
#   'lastAction': 'Pass'},
#  {'id': '281752',
#   'minute': '58',
#   'result': 'MissedShots',
#   'X': '0.9',
#   'Y': '0.6329999923706054',
#   'xG': '0.10104499757289886',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10199',
#   'h_team': 'Levante',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2019-02-24 19:45:00',
#   'player_assisted': 'Luka Modric',
#   'lastAction': 'Pass'},
#  {'id': '281754',
#   'minute': '64',
#   'result': 'BlockedShot',
#   'X': '0.88',
#   'Y': '0.639000015258789',
#   'xG': '0.059602200984954834',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10199',
#   'h_team': 'Levante',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2019-02-24 19:45:00',
#   'player_assisted': 'Toni Kroos',
#   'lastAction': 'Chipped'},
#  {'id': '281757',
#   'minute': '70',
#   'result': 'SavedShot',
#   'X': '0.8819999694824219',
#   'Y': '0.639000015258789',
#   'xG': '0.4914740025997162',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10199',
#   'h_team': 'Levante',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2019-02-24 19:45:00',
#   'player_assisted': 'Lucas Vázquez',
#   'lastAction': 'Throughball'},
#  {'id': '281902',
#   'minute': '27',
#   'result': 'BlockedShot',
#   'X': '0.855',
#   'Y': '0.639000015258789',
#   'xG': '0.058544501662254333',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'FromCorner',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10207',
#   'h_team': 'Real Madrid',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2019-03-02 19:45:00',
#   'player_assisted': None,
#   'lastAction': 'Rebound'},
#  {'id': '281908',
#   'minute': '42',
#   'result': 'MissedShots',
#   'X': '0.8719999694824219',
#   'Y': '0.6840000152587891',
#   'xG': '0.040908701717853546',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10207',
#   'h_team': 'Real Madrid',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2019-03-02 19:45:00',
#   'player_assisted': 'Luka Modric',
#   'lastAction': 'Pass'},
#  {'id': '281910',
#   'minute': '55',
#   'result': 'SavedShot',
#   'X': '0.875999984741211',
#   'Y': '0.6469999694824219',
#   'xG': '0.057679299265146255',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'SetPiece',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10207',
#   'h_team': 'Real Madrid',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2019-03-02 19:45:00',
#   'player_assisted': 'Sergio Ramos',
#   'lastAction': 'Chipped'},
#  {'id': '281912',
#   'minute': '58',
#   'result': 'BlockedShot',
#   'X': '0.895',
#   'Y': '0.5570000076293945',
#   'xG': '0.07952229678630829',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10207',
#   'h_team': 'Real Madrid',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2019-03-02 19:45:00',
#   'player_assisted': None,
#   'lastAction': 'BlockedPass'},
#  {'id': '281915',
#   'minute': '71',
#   'result': 'MissedShots',
#   'X': '0.7609999847412109',
#   'Y': '0.5929999923706055',
#   'xG': '0.023652000352740288',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10207',
#   'h_team': 'Real Madrid',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2019-03-02 19:45:00',
#   'player_assisted': 'Federico Valverde',
#   'lastAction': 'Pass'},
#  {'id': '281918',
#   'minute': '90',
#   'result': 'BlockedShot',
#   'X': '0.8580000305175781',
#   'Y': '0.6780000305175782',
#   'xG': '0.03858819976449013',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'FromCorner',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10207',
#   'h_team': 'Real Madrid',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2019-03-02 19:45:00',
#   'player_assisted': 'Isco',
#   'lastAction': 'Pass'},
#  {'id': '300076',
#   'minute': '81',
#   'result': 'SavedShot',
#   'X': '0.889000015258789',
#   'Y': '0.6',
#   'xG': '0.10378599911928177',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10312',
#   'h_team': 'Real Madrid',
#   'a_team': 'Villarreal',
#   'h_goals': '3',
#   'a_goals': '2',
#   'date': '2019-05-05 15:15:00',
#   'player_assisted': None,
#   'lastAction': 'BallTouch'},
#  {'id': '300077',
#   'minute': '84',
#   'result': 'MissedShots',
#   'X': '0.8619999694824219',
#   'Y': '0.7380000305175781',
#   'xG': '0.02931779995560646',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10312',
#   'h_team': 'Real Madrid',
#   'a_team': 'Villarreal',
#   'h_goals': '3',
#   'a_goals': '2',
#   'date': '2019-05-05 15:15:00',
#   'player_assisted': 'Daniel Carvajal',
#   'lastAction': 'Cross'},
#  {'id': '303061',
#   'minute': '31',
#   'result': 'BlockedShot',
#   'X': '0.8030000305175782',
#   'Y': '0.47200000762939454',
#   'xG': '0.03289970010519028',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'SetPiece',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10328',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Betis',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2019-05-19 10:00:00',
#   'player_assisted': 'Brahim Diaz',
#   'lastAction': 'Pass'},
#  {'id': '303067',
#   'minute': '56',
#   'result': 'SavedShot',
#   'X': '0.965999984741211',
#   'Y': '0.62',
#   'xG': '0.25868698954582214',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'LeftFoot',
#   'match_id': '10328',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Betis',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2019-05-19 10:00:00',
#   'player_assisted': 'Marcelo',
#   'lastAction': 'TakeOn'},
#  {'id': '303069',
#   'minute': '63',
#   'result': 'MissedShots',
#   'X': '0.85',
#   'Y': '0.7019999694824218',
#   'xG': '0.030116699635982513',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2018',
#   'shotType': 'RightFoot',
#   'match_id': '10328',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Betis',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2019-05-19 10:00:00',
#   'player_assisted': 'Federico Valverde',
#   'lastAction': 'Pass'},
#  {'id': '317007',
#   'minute': '56',
#   'result': 'MissedShots',
#   'X': '0.9159999847412109',
#   'Y': '0.705999984741211',
#   'xG': '0.21282799541950226',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12060',
#   'h_team': 'Real Madrid',
#   'a_team': 'Levante',
#   'h_goals': '3',
#   'a_goals': '2',
#   'date': '2019-09-14 11:00:00',
#   'player_assisted': None,
#   'lastAction': 'Rebound'},
#  {'id': '317008',
#   'minute': '61',
#   'result': 'BlockedShot',
#   'X': '0.9209999847412109',
#   'Y': '0.515',
#   'xG': '0.14451700448989868',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12060',
#   'h_team': 'Real Madrid',
#   'a_team': 'Levante',
#   'h_goals': '3',
#   'a_goals': '2',
#   'date': '2019-09-14 11:00:00',
#   'player_assisted': 'Eden Hazard',
#   'lastAction': 'Pass'},
#  {'id': '317009',
#   'minute': '61',
#   'result': 'SavedShot',
#   'X': '0.8780000305175781',
#   'Y': '0.49700000762939456',
#   'xG': '0.13835300505161285',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12060',
#   'h_team': 'Real Madrid',
#   'a_team': 'Levante',
#   'h_goals': '3',
#   'a_goals': '2',
#   'date': '2019-09-14 11:00:00',
#   'player_assisted': 'Marcelo',
#   'lastAction': 'Pass'},
#  {'id': '317012',
#   'minute': '69',
#   'result': 'MissedShots',
#   'X': '0.905',
#   'Y': '0.539000015258789',
#   'xG': '0.04176820069551468',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'Head',
#   'match_id': '12060',
#   'h_team': 'Real Madrid',
#   'a_team': 'Levante',
#   'h_goals': '3',
#   'a_goals': '2',
#   'date': '2019-09-14 11:00:00',
#   'player_assisted': 'Marcelo',
#   'lastAction': 'Aerial'},
#  {'id': '317013',
#   'minute': '70',
#   'result': 'SavedShot',
#   'X': '0.9059999847412109',
#   'Y': '0.43099998474121093',
#   'xG': '0.391092985868454',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12060',
#   'h_team': 'Real Madrid',
#   'a_team': 'Levante',
#   'h_goals': '3',
#   'a_goals': '2',
#   'date': '2019-09-14 11:00:00',
#   'player_assisted': 'James Rodríguez',
#   'lastAction': 'Chipped'},
#  {'id': '321958',
#   'minute': '35',
#   'result': 'Goal',
#   'X': '0.7909999847412109',
#   'Y': '0.6370000076293946',
#   'xG': '0.029101399704813957',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12078',
#   'h_team': 'Real Madrid',
#   'a_team': 'Osasuna',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2019-09-25 19:00:00',
#   'player_assisted': 'Toni Kroos',
#   'lastAction': 'Pass'},
#  {'id': '321959',
#   'minute': '38',
#   'result': 'MissedShots',
#   'X': '0.735999984741211',
#   'Y': '0.39099998474121095',
#   'xG': '0.020115099847316742',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12078',
#   'h_team': 'Real Madrid',
#   'a_team': 'Osasuna',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2019-09-25 19:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '326675',
#   'minute': '14',
#   'result': 'MissedShots',
#   'X': '0.815',
#   'Y': '0.55',
#   'xG': '0.05448339879512787',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12110',
#   'h_team': 'Mallorca',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '0',
#   'date': '2019-10-19 20:00:00',
#   'player_assisted': 'Álvaro Odriozola',
#   'lastAction': 'Pass'},
#  {'id': '326677',
#   'minute': '24',
#   'result': 'MissedShots',
#   'X': '0.8219999694824218',
#   'Y': '0.55',
#   'xG': '0.12478599697351456',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12110',
#   'h_team': 'Mallorca',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '0',
#   'date': '2019-10-19 20:00:00',
#   'player_assisted': None,
#   'lastAction': 'TakeOn'},
#  {'id': '326678',
#   'minute': '25',
#   'result': 'BlockedShot',
#   'X': '0.8719999694824219',
#   'Y': '0.705999984741211',
#   'xG': '0.03808550164103508',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12110',
#   'h_team': 'Mallorca',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '0',
#   'date': '2019-10-19 20:00:00',
#   'player_assisted': 'Casemiro',
#   'lastAction': 'Chipped'},
#  {'id': '329628',
#   'minute': '89',
#   'result': 'SavedShot',
#   'X': '0.965999984741211',
#   'Y': '0.27',
#   'xG': '0.019378600642085075',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12139',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Betis',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2019-11-02 20:00:00',
#   'player_assisted': 'Eden Hazard',
#   'lastAction': 'Cross'},
#  {'id': '329629',
#   'minute': '90',
#   'result': 'SavedShot',
#   'X': '0.950999984741211',
#   'Y': '0.395',
#   'xG': '0.2990500032901764',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12139',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Betis',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2019-11-02 20:00:00',
#   'player_assisted': 'Ferland Mendy',
#   'lastAction': 'Cross'},
#  {'id': '329630',
#   'minute': '91',
#   'result': 'BlockedShot',
#   'X': '0.899000015258789',
#   'Y': '0.33599998474121096',
#   'xG': '0.024283399805426598',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'FromCorner',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12139',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Betis',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2019-11-02 20:00:00',
#   'player_assisted': None,
#   'lastAction': 'Aerial'},
#  {'id': '335438',
#   'minute': '5',
#   'result': 'SavedShot',
#   'X': '0.9030000305175782',
#   'Y': '0.6580000305175782',
#   'xG': '0.08978009968996048',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12180',
#   'h_team': 'Real Madrid',
#   'a_team': 'Espanyol',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2019-12-07 12:00:00',
#   'player_assisted': 'Karim Benzema',
#   'lastAction': 'TakeOn'},
#  {'id': '335444',
#   'minute': '26',
#   'result': 'SavedShot',
#   'X': '0.9580000305175781',
#   'Y': '0.6580000305175782',
#   'xG': '0.08111529797315598',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12180',
#   'h_team': 'Real Madrid',
#   'a_team': 'Espanyol',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2019-12-07 12:00:00',
#   'player_assisted': 'Karim Benzema',
#   'lastAction': 'TakeOn'},
#  {'id': '335447',
#   'minute': '42',
#   'result': 'SavedShot',
#   'X': '0.9490000152587891',
#   'Y': '0.66',
#   'xG': '0.1009799987077713',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12180',
#   'h_team': 'Real Madrid',
#   'a_team': 'Espanyol',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2019-12-07 12:00:00',
#   'player_assisted': 'Karim Benzema',
#   'lastAction': 'Pass'},
#  {'id': '335454',
#   'minute': '65',
#   'result': 'BlockedShot',
#   'X': '0.8669999694824219',
#   'Y': '0.6609999847412109',
#   'xG': '0.06733699887990952',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12180',
#   'h_team': 'Real Madrid',
#   'a_team': 'Espanyol',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2019-12-07 12:00:00',
#   'player_assisted': 'Karim Benzema',
#   'lastAction': 'Pass'},
#  {'id': '337865',
#   'minute': '72',
#   'result': 'BlockedShot',
#   'X': '0.87',
#   'Y': '0.6229999923706054',
#   'xG': '0.08130539953708649',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12192',
#   'h_team': 'Valencia',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '1',
#   'date': '2019-12-15 20:00:00',
#   'player_assisted': 'Karim Benzema',
#   'lastAction': 'Pass'},
#  {'id': '339453',
#   'minute': '10',
#   'result': 'SavedShot',
#   'X': '0.9319999694824219',
#   'Y': '0.6079999923706054',
#   'xG': '0.16603399813175201',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12200',
#   'h_team': 'Real Madrid',
#   'a_team': 'Athletic Club',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2019-12-22 20:00:00',
#   'player_assisted': 'Karim Benzema',
#   'lastAction': 'TakeOn'},
#  {'id': '339459',
#   'minute': '23',
#   'result': 'SavedShot',
#   'X': '0.924000015258789',
#   'Y': '0.59',
#   'xG': '0.05039820075035095',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'Head',
#   'match_id': '12200',
#   'h_team': 'Real Madrid',
#   'a_team': 'Athletic Club',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2019-12-22 20:00:00',
#   'player_assisted': 'Luka Modric',
#   'lastAction': 'Chipped'},
#  {'id': '353690',
#   'minute': '88',
#   'result': 'MissedShots',
#   'X': '0.919000015258789',
#   'Y': '0.6719999694824219',
#   'xG': '0.2835629880428314',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'LeftFoot',
#   'match_id': '12207',
#   'h_team': 'Getafe',
#   'a_team': 'Real Madrid',
#   'h_goals': '0',
#   'a_goals': '3',
#   'date': '2020-01-04 15:00:00',
#   'player_assisted': 'Luka Jovic',
#   'lastAction': 'Pass'},
#  {'id': '354927',
#   'minute': '62',
#   'result': 'MissedShots',
#   'X': '0.874000015258789',
#   'Y': '0.675',
#   'xG': '0.05705000087618828',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12221',
#   'h_team': 'Real Madrid',
#   'a_team': 'Sevilla',
#   'h_goals': '2',
#   'a_goals': '1',
#   'date': '2020-01-18 15:00:00',
#   'player_assisted': 'Toni Kroos',
#   'lastAction': 'Pass'},
#  {'id': '356711',
#   'minute': '63',
#   'result': 'SavedShot',
#   'X': '0.8590000152587891',
#   'Y': '0.7719999694824219',
#   'xG': '0.03437339887022972',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12238',
#   'h_team': 'Real Madrid',
#   'a_team': 'Atletico Madrid',
#   'h_goals': '1',
#   'a_goals': '0',
#   'date': '2020-02-01 15:00:00',
#   'player_assisted': 'Federico Valverde',
#   'lastAction': 'Chipped'},
#  {'id': '356716',
#   'minute': '80',
#   'result': 'SavedShot',
#   'X': '0.8719999694824219',
#   'Y': '0.5979999923706054',
#   'xG': '0.09827470034360886',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12238',
#   'h_team': 'Real Madrid',
#   'a_team': 'Atletico Madrid',
#   'h_goals': '1',
#   'a_goals': '0',
#   'date': '2020-02-01 15:00:00',
#   'player_assisted': 'Karim Benzema',
#   'lastAction': 'Pass'},
#  {'id': '358531',
#   'minute': '83',
#   'result': 'BlockedShot',
#   'X': '0.8090000152587891',
#   'Y': '0.5320000076293945',
#   'xG': '0.07202179729938507',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12246',
#   'h_team': 'Osasuna',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '4',
#   'date': '2020-02-09 15:00:00',
#   'player_assisted': None,
#   'lastAction': 'BallRecovery'},
#  {'id': '358534',
#   'minute': '90',
#   'result': 'MissedShots',
#   'X': '0.8959999847412109',
#   'Y': '0.67',
#   'xG': '0.0810772031545639',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12246',
#   'h_team': 'Osasuna',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '4',
#   'date': '2020-02-09 15:00:00',
#   'player_assisted': 'Luka Modric',
#   'lastAction': 'Pass'},
#  {'id': '361468',
#   'minute': '36',
#   'result': 'SavedShot',
#   'X': '0.8469999694824218',
#   'Y': '0.6969999694824218',
#   'xG': '0.054329998791217804',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12279',
#   'h_team': 'Real Madrid',
#   'a_team': 'Barcelona',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2020-03-01 20:00:00',
#   'player_assisted': 'Isco',
#   'lastAction': 'Pass'},
#  {'id': '361478',
#   'minute': '70',
#   'result': 'Goal',
#   'X': '0.9569999694824218',
#   'Y': '0.6769999694824219',
#   'xG': '0.05314449965953827',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12279',
#   'h_team': 'Real Madrid',
#   'a_team': 'Barcelona',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2020-03-01 20:00:00',
#   'player_assisted': 'Toni Kroos',
#   'lastAction': 'Pass'},
#  {'id': '362390',
#   'minute': '15',
#   'result': 'MissedShots',
#   'X': '0.8819999694824219',
#   'Y': '0.675',
#   'xG': '0.061591099947690964',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12286',
#   'h_team': 'Real Betis',
#   'a_team': 'Real Madrid',
#   'h_goals': '2',
#   'a_goals': '1',
#   'date': '2020-03-08 20:00:00',
#   'player_assisted': 'Karim Benzema',
#   'lastAction': 'BallTouch'},
#  {'id': '362410',
#   'minute': '84',
#   'result': 'BlockedShot',
#   'X': '0.919000015258789',
#   'Y': '0.37099998474121093',
#   'xG': '0.025945499539375305',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'OtherBodyPart',
#   'match_id': '12286',
#   'h_team': 'Real Betis',
#   'a_team': 'Real Madrid',
#   'h_goals': '2',
#   'a_goals': '1',
#   'date': '2020-03-08 20:00:00',
#   'player_assisted': 'Lucas Vázquez',
#   'lastAction': 'Cross'},
#  {'id': '362414',
#   'minute': '93',
#   'result': 'MissedShots',
#   'X': '0.7809999847412109',
#   'Y': '0.62',
#   'xG': '0.029831400141119957',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12286',
#   'h_team': 'Real Betis',
#   'a_team': 'Real Madrid',
#   'h_goals': '2',
#   'a_goals': '1',
#   'date': '2020-03-08 20:00:00',
#   'player_assisted': 'Karim Benzema',
#   'lastAction': 'Pass'},
#  {'id': '365908',
#   'minute': '1',
#   'result': 'MissedShots',
#   'X': '0.8959999847412109',
#   'Y': '0.4490000152587891',
#   'xG': '0.12425000220537186',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12320',
#   'h_team': 'Real Sociedad',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2020-06-21 20:00:00',
#   'player_assisted': 'Federico Valverde',
#   'lastAction': 'Pass'},
#  {'id': '365915',
#   'minute': '42',
#   'result': 'SavedShot',
#   'X': '0.87',
#   'Y': '0.6140000152587891',
#   'xG': '0.10155399888753891',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12320',
#   'h_team': 'Real Sociedad',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2020-06-21 20:00:00',
#   'player_assisted': None,
#   'lastAction': 'TakeOn'},
#  {'id': '366525',
#   'minute': '15',
#   'result': 'BlockedShot',
#   'X': '0.88',
#   'Y': '0.605999984741211',
#   'xG': '0.08960279822349548',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12329',
#   'h_team': 'Real Madrid',
#   'a_team': 'Mallorca',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2020-06-24 20:00:00',
#   'player_assisted': 'Eden Hazard',
#   'lastAction': 'Pass'},
#  {'id': '366527',
#   'minute': '18',
#   'result': 'Goal',
#   'X': '0.9580000305175781',
#   'Y': '0.625999984741211',
#   'xG': '0.3681730031967163',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12329',
#   'h_team': 'Real Madrid',
#   'a_team': 'Mallorca',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2020-06-24 20:00:00',
#   'player_assisted': 'Luka Modric',
#   'lastAction': 'Throughball'},
#  {'id': '366529',
#   'minute': '23',
#   'result': 'ShotOnPost',
#   'X': '0.8590000152587891',
#   'Y': '0.605999984741211',
#   'xG': '0.3440989851951599',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12329',
#   'h_team': 'Real Madrid',
#   'a_team': 'Mallorca',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2020-06-24 20:00:00',
#   'player_assisted': 'Karim Benzema',
#   'lastAction': 'Throughball'},
#  {'id': '368464',
#   'minute': '22',
#   'result': 'SavedShot',
#   'X': '0.9119999694824219',
#   'Y': '0.49900001525878906',
#   'xG': '0.3794200122356415',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12349',
#   'h_team': 'Real Madrid',
#   'a_team': 'Getafe',
#   'h_goals': '1',
#   'a_goals': '0',
#   'date': '2020-07-02 20:00:00',
#   'player_assisted': 'Ferland Mendy',
#   'lastAction': 'Cross'},
#  {'id': '371991',
#   'minute': '79',
#   'result': 'BlockedShot',
#   'X': '0.855',
#   'Y': '0.6630000305175782',
#   'xG': '0.07302500307559967',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2019',
#   'shotType': 'RightFoot',
#   'match_id': '12390',
#   'h_team': 'Real Madrid',
#   'a_team': 'Villarreal',
#   'h_goals': '2',
#   'a_goals': '1',
#   'date': '2020-07-16 19:00:00',
#   'player_assisted': 'Karim Benzema',
#   'lastAction': 'Pass'},
#  {'id': '378349',
#   'minute': '38',
#   'result': 'MissedShots',
#   'X': '0.845',
#   'Y': '0.5540000152587891',
#   'xG': '0.05492430180311203',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2020',
#   'shotType': 'RightFoot',
#   'match_id': '14152',
#   'h_team': 'Real Sociedad',
#   'a_team': 'Real Madrid',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2020-09-20 19:00:00',
#   'player_assisted': 'Ferland Mendy',
#   'lastAction': 'Chipped'},
#  {'id': '378362',
#   'minute': '81',
#   'result': 'BlockedShot',
#   'X': '0.7919999694824219',
#   'Y': '0.67',
#   'xG': '0.026425199583172798',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2020',
#   'shotType': 'RightFoot',
#   'match_id': '14152',
#   'h_team': 'Real Sociedad',
#   'a_team': 'Real Madrid',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2020-09-20 19:00:00',
#   'player_assisted': 'Toni Kroos',
#   'lastAction': 'Pass'},
#  {'id': '380185',
#   'minute': '64',
#   'result': 'Goal',
#   'X': '0.9290000152587891',
#   'Y': '0.54',
#   'xG': '0.5403940081596375',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2020',
#   'shotType': 'RightFoot',
#   'match_id': '14169',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Valladolid',
#   'h_goals': '1',
#   'a_goals': '0',
#   'date': '2020-09-30 19:30:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '380190',
#   'minute': '76',
#   'result': 'BlockedShot',
#   'X': '0.889000015258789',
#   'Y': '0.5429999923706055',
#   'xG': '0.1513260006904602',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2020',
#   'shotType': 'RightFoot',
#   'match_id': '14169',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Valladolid',
#   'h_goals': '1',
#   'a_goals': '0',
#   'date': '2020-09-30 19:30:00',
#   'player_assisted': 'Karim Benzema',
#   'lastAction': 'Pass'},
#  {'id': '380195',
#   'minute': '92',
#   'result': 'SavedShot',
#   'X': '0.8440000152587891',
#   'Y': '0.5870000076293945',
#   'xG': '0.13850300014019012',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2020',
#   'shotType': 'LeftFoot',
#   'match_id': '14169',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Valladolid',
#   'h_goals': '1',
#   'a_goals': '0',
#   'date': '2020-09-30 19:30:00',
#   'player_assisted': 'Federico Valverde',
#   'lastAction': 'TakeOn'},
#  {'id': '381304',
#   'minute': '15',
#   'result': 'Goal',
#   'X': '0.8909999847412109',
#   'Y': '0.6480000305175782',
#   'xG': '0.054593801498413086',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'FromCorner',
#   'season': '2020',
#   'shotType': 'RightFoot',
#   'match_id': '14819',
#   'h_team': 'Levante',
#   'a_team': 'Real Madrid',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2020-10-04 14:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '381313',
#   'minute': '51',
#   'result': 'MissedShots',
#   'X': '0.9630000305175781',
#   'Y': '0.3890000152587891',
#   'xG': '0.42011401057243347',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2020',
#   'shotType': 'RightFoot',
#   'match_id': '14819',
#   'h_team': 'Levante',
#   'a_team': 'Real Madrid',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2020-10-04 14:00:00',
#   'player_assisted': 'Marco Asensio',
#   'lastAction': 'Throughball'},
#  {'id': '381314',
#   'minute': '54',
#   'result': 'MissedShots',
#   'X': '0.955',
#   'Y': '0.5209999847412109',
#   'xG': '0.663079023361206',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2020',
#   'shotType': 'RightFoot',
#   'match_id': '14819',
#   'h_team': 'Levante',
#   'a_team': 'Real Madrid',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2020-10-04 14:00:00',
#   'player_assisted': 'Karim Benzema',
#   'lastAction': 'Pass'},
#  {'id': '382082',
#   'minute': '40',
#   'result': 'BlockedShot',
#   'X': '0.895',
#   'Y': '0.5029999923706054',
#   'xG': '0.0795757994055748',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2020',
#   'shotType': 'RightFoot',
#   'match_id': '14833',
#   'h_team': 'Real Madrid',
#   'a_team': 'Cadiz',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2020-10-17 16:30:00',
#   'player_assisted': 'Lucas Vázquez',
#   'lastAction': 'HeadPass'},
#  {'id': '382083',
#   'minute': '48',
#   'result': 'BlockedShot',
#   'X': '0.860999984741211',
#   'Y': '0.6659999847412109',
#   'xG': '0.04679720103740692',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2020',
#   'shotType': 'RightFoot',
#   'match_id': '14833',
#   'h_team': 'Real Madrid',
#   'a_team': 'Cadiz',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2020-10-17 16:30:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '382085',
#   'minute': '54',
#   'result': 'MissedShots',
#   'X': '0.8640000152587891',
#   'Y': '0.639000015258789',
#   'xG': '0.0535162016749382',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2020',
#   'shotType': 'RightFoot',
#   'match_id': '14833',
#   'h_team': 'Real Madrid',
#   'a_team': 'Cadiz',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2020-10-17 16:30:00',
#   'player_assisted': 'Toni Kroos',
#   'lastAction': 'Pass'},
#  {'id': '382089',
#   'minute': '66',
#   'result': 'MissedShots',
#   'X': '0.935',
#   'Y': '0.49900001525878906',
#   'xG': '0.4785119891166687',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2020',
#   'shotType': 'Head',
#   'match_id': '14833',
#   'h_team': 'Real Madrid',
#   'a_team': 'Cadiz',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2020-10-17 16:30:00',
#   'player_assisted': 'Toni Kroos',
#   'lastAction': 'Cross'},
#  {'id': '383325',
#   'minute': '86',
#   'result': 'SavedShot',
#   'X': '0.7609999847412109',
#   'Y': '0.4909999847412109',
#   'xG': '0.0335782989859581',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2020',
#   'shotType': 'RightFoot',
#   'match_id': '14836',
#   'h_team': 'Barcelona',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '3',
#   'date': '2020-10-24 14:00:00',
#   'player_assisted': 'Luka Modric',
#   'lastAction': 'Pass'},
#  {'id': '387011',
#   'minute': '56',
#   'result': 'MissedShots',
#   'X': '0.9290000152587891',
#   'Y': '0.6840000152587891',
#   'xG': '0.03980100154876709',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2020',
#   'shotType': 'RightFoot',
#   'match_id': '14862',
#   'h_team': 'Valencia',
#   'a_team': 'Real Madrid',
#   'h_goals': '4',
#   'a_goals': '1',
#   'date': '2020-11-08 20:00:00',
#   'player_assisted': None,
#   'lastAction': 'Rebound'},
#  {'id': '389042',
#   'minute': '85',
#   'result': 'SavedShot',
#   'X': '0.9540000152587891',
#   'Y': '0.5590000152587891',
#   'xG': '0.11952900141477585',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2020',
#   'shotType': 'RightFoot',
#   'match_id': '14880',
#   'h_team': 'Real Madrid',
#   'a_team': 'Alaves',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2020-11-28 20:00:00',
#   'player_assisted': 'Raphael Varane',
#   'lastAction': 'Rebound'},
#  {'id': '390175',
#   'minute': '0',
#   'result': 'MissedShots',
#   'X': '0.9619999694824218',
#   'Y': '0.34599998474121096',
#   'xG': '0.08045949786901474',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2020',
#   'shotType': 'RightFoot',
#   'match_id': '14889',
#   'h_team': 'Sevilla',
#   'a_team': 'Real Madrid',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2020-12-05 15:15:00',
#   'player_assisted': 'Rodrygo',
#   'lastAction': 'Pass'},
#  {'id': '390185',
#   'minute': '54',
#   'result': 'MissedShots',
#   'X': '0.9169999694824219',
#   'Y': '0.5479999923706055',
#   'xG': '0.4691050052642822',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2020',
#   'shotType': 'RightFoot',
#   'match_id': '14889',
#   'h_team': 'Sevilla',
#   'a_team': 'Real Madrid',
#   'h_goals': '0',
#   'a_goals': '1',
#   'date': '2020-12-05 15:15:00',
#   'player_assisted': None,
#   'lastAction': 'Foul'},
#  {'id': '392749',
#   'minute': '34',
#   'result': 'MissedShots',
#   'X': '0.7880000305175782',
#   'Y': '0.6780000305175782',
#   'xG': '0.025523599237203598',
#   'player': 'Vinícius Júnior',
# ...
#   'season': '2023',
#   'shotType': 'RightFoot',
#   'match_id': '23063',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Betis',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2024-05-25 19:00:00',
#   'player_assisted': 'Rodrygo',
#   'lastAction': 'Pass'},
#  {'id': '583393',
#   'minute': '74',
#   'result': 'MissedShots',
#   'X': '0.8080000305175781',
#   'Y': '0.53',
#   'xG': '0.05553634092211723',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2023',
#   'shotType': 'RightFoot',
#   'match_id': '23063',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Betis',
#   'h_goals': '0',
#   'a_goals': '0',
#   'date': '2024-05-25 19:00:00',
#   'player_assisted': 'Rodrygo',
#   'lastAction': 'Pass'},
#  {'id': '585524',
#   'minute': '60',
#   'result': 'MissedShots',
#   'X': '0.8280000305175781',
#   'Y': '0.720999984741211',
#   'xG': '0.045298099517822266',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '26989',
#   'h_team': 'Mallorca',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '1',
#   'date': '2024-08-18 19:30:00',
#   'player_assisted': 'Jude Bellingham',
#   'lastAction': 'Pass'},
#  {'id': '585526',
#   'minute': '63',
#   'result': 'BlockedShot',
#   'X': '0.7619999694824219',
#   'Y': '0.3970000076293945',
#   'xG': '0.024782655760645866',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'LeftFoot',
#   'match_id': '26989',
#   'h_team': 'Mallorca',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '1',
#   'date': '2024-08-18 19:30:00',
#   'player_assisted': 'Federico Valverde',
#   'lastAction': 'Pass'},
#  {'id': '586769',
#   'minute': '81',
#   'result': 'BlockedShot',
#   'X': '0.8469999694824218',
#   'Y': '0.624000015258789',
#   'xG': '0.08243653923273087',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '26998',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Valladolid',
#   'h_goals': '3',
#   'a_goals': '0',
#   'date': '2024-08-25 15:00:00',
#   'player_assisted': 'Fran García',
#   'lastAction': 'Pass'},
#  {'id': '587378',
#   'minute': '3',
#   'result': 'MissedShots',
#   'X': '0.8530000305175781',
#   'Y': '0.6609999847412109',
#   'xG': '0.0559794157743454',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '27011',
#   'h_team': 'Las Palmas',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '1',
#   'date': '2024-08-29 19:30:00',
#   'player_assisted': None,
#   'lastAction': 'BallRecovery'},
#  {'id': '587389',
#   'minute': '50',
#   'result': 'SavedShot',
#   'X': '0.87',
#   'Y': '0.6819999694824219',
#   'xG': '0.04529854655265808',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'LeftFoot',
#   'match_id': '27011',
#   'h_team': 'Las Palmas',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '1',
#   'date': '2024-08-29 19:30:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '587395',
#   'minute': '54',
#   'result': 'MissedShots',
#   'X': '0.8969999694824219',
#   'Y': '0.5',
#   'xG': '0.2798962891101837',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'Head',
#   'match_id': '27011',
#   'h_team': 'Las Palmas',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '1',
#   'date': '2024-08-29 19:30:00',
#   'player_assisted': None,
#   'lastAction': 'Rebound'},
#  {'id': '587399',
#   'minute': '66',
#   'result': 'MissedShots',
#   'X': '0.9180000305175782',
#   'Y': '0.45099998474121095',
#   'xG': '0.12786737084388733',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'LeftFoot',
#   'match_id': '27011',
#   'h_team': 'Las Palmas',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '1',
#   'date': '2024-08-29 19:30:00',
#   'player_assisted': 'Lucas Vázquez',
#   'lastAction': 'Pass'},
#  {'id': '587401',
#   'minute': '68',
#   'result': 'Goal',
#   'X': '0.885',
#   'Y': '0.5',
#   'xG': '0.7432776093482971',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'Penalty',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '27011',
#   'h_team': 'Las Palmas',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '1',
#   'date': '2024-08-29 19:30:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '587404',
#   'minute': '72',
#   'result': 'MissedShots',
#   'X': '0.835999984741211',
#   'Y': '0.7440000152587891',
#   'xG': '0.041609711945056915',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '27011',
#   'h_team': 'Las Palmas',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '1',
#   'date': '2024-08-29 19:30:00',
#   'player_assisted': 'Federico Valverde',
#   'lastAction': 'Pass'},
#  {'id': '590246',
#   'minute': '25',
#   'result': 'BlockedShot',
#   'X': '0.8490000152587891',
#   'Y': '0.46799999237060547',
#   'xG': '0.09498214721679688',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '27021',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Betis',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2024-09-01 19:30:00',
#   'player_assisted': 'Rodrygo',
#   'lastAction': 'Pass'},
#  {'id': '590256',
#   'minute': '49',
#   'result': 'BlockedShot',
#   'X': '0.8490000152587891',
#   'Y': '0.6790000152587891',
#   'xG': '0.039027608931064606',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '27021',
#   'h_team': 'Real Madrid',
#   'a_team': 'Real Betis',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2024-09-01 19:30:00',
#   'player_assisted': 'Federico Valverde',
#   'lastAction': 'Chipped'},
#  {'id': '591140',
#   'minute': '21',
#   'result': 'BlockedShot',
#   'X': '0.8590000152587891',
#   'Y': '0.625999984741211',
#   'xG': '0.06915722042322159',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '27031',
#   'h_team': 'Real Sociedad',
#   'a_team': 'Real Madrid',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2024-09-14 19:00:00',
#   'player_assisted': 'Arda Güler',
#   'lastAction': 'Pass'},
#  {'id': '591149',
#   'minute': '42',
#   'result': 'BlockedShot',
#   'X': '0.7469999694824219',
#   'Y': '0.6',
#   'xG': '0.015781691297888756',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '27031',
#   'h_team': 'Real Sociedad',
#   'a_team': 'Real Madrid',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2024-09-14 19:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '591153',
#   'minute': '47',
#   'result': 'BlockedShot',
#   'X': '0.895',
#   'Y': '0.6809999847412109',
#   'xG': '0.04852623865008354',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'LeftFoot',
#   'match_id': '27031',
#   'h_team': 'Real Sociedad',
#   'a_team': 'Real Madrid',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2024-09-14 19:00:00',
#   'player_assisted': 'Kylian Mbappe-Lottin',
#   'lastAction': 'Pass'},
#  {'id': '591157',
#   'minute': '57',
#   'result': 'Goal',
#   'X': '0.885',
#   'Y': '0.5',
#   'xG': '0.7432776093482971',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'Penalty',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '27031',
#   'h_team': 'Real Sociedad',
#   'a_team': 'Real Madrid',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2024-09-14 19:00:00',
#   'player_assisted': None,
#   'lastAction': 'Standard'},
#  {'id': '591161',
#   'minute': '85',
#   'result': 'BlockedShot',
#   'X': '0.8369999694824218',
#   'Y': '0.5970000076293945',
#   'xG': '0.08994334936141968',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '27031',
#   'h_team': 'Real Sociedad',
#   'a_team': 'Real Madrid',
#   'h_goals': '0',
#   'a_goals': '2',
#   'date': '2024-09-14 19:00:00',
#   'player_assisted': 'Rodrygo',
#   'lastAction': 'Pass'},
#  {'id': '592803',
#   'minute': '55',
#   'result': 'MissedShots',
#   'X': '0.725999984741211',
#   'Y': '0.40099998474121096',
#   'xG': '0.017971787601709366',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '27041',
#   'h_team': 'Real Madrid',
#   'a_team': 'Espanyol',
#   'h_goals': '4',
#   'a_goals': '1',
#   'date': '2024-09-21 19:00:00',
#   'player_assisted': 'Luka Modric',
#   'lastAction': 'Pass'},
#  {'id': '592817',
#   'minute': '77',
#   'result': 'Goal',
#   'X': '0.9019999694824219',
#   'Y': '0.6190000152587891',
#   'xG': '0.3479388356208801',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'LeftFoot',
#   'match_id': '27041',
#   'h_team': 'Real Madrid',
#   'a_team': 'Espanyol',
#   'h_goals': '4',
#   'a_goals': '1',
#   'date': '2024-09-21 19:00:00',
#   'player_assisted': 'Kylian Mbappe-Lottin',
#   'lastAction': 'Pass'},
#  {'id': '593472',
#   'minute': '45',
#   'result': 'BlockedShot',
#   'X': '0.8430000305175781',
#   'Y': '0.7480000305175781',
#   'xG': '0.020013432949781418',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '27051',
#   'h_team': 'Real Madrid',
#   'a_team': 'Alaves',
#   'h_goals': '3',
#   'a_goals': '2',
#   'date': '2024-09-24 19:00:00',
#   'player_assisted': None,
#   'lastAction': 'Rebound'},
#  {'id': '593471',
#   'minute': '45',
#   'result': 'BlockedShot',
#   'X': '0.919000015258789',
#   'Y': '0.6880000305175781',
#   'xG': '0.09470430761575699',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'LeftFoot',
#   'match_id': '27051',
#   'h_team': 'Real Madrid',
#   'a_team': 'Alaves',
#   'h_goals': '3',
#   'a_goals': '2',
#   'date': '2024-09-24 19:00:00',
#   'player_assisted': 'Eder Militão',
#   'lastAction': 'Chipped'},
#  {'id': '593475',
#   'minute': '51',
#   'result': 'MissedShots',
#   'X': '0.9109999847412109',
#   'Y': '0.5359999847412109',
#   'xG': '0.1368151754140854',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'LeftFoot',
#   'match_id': '27051',
#   'h_team': 'Real Madrid',
#   'a_team': 'Alaves',
#   'h_goals': '3',
#   'a_goals': '2',
#   'date': '2024-09-24 19:00:00',
#   'player_assisted': None,
#   'lastAction': 'TakeOn'},
#  {'id': '594982',
#   'minute': '72',
#   'result': 'SavedShot',
#   'X': '0.8',
#   'Y': '0.54',
#   'xG': '0.05662938952445984',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'LeftFoot',
#   'match_id': '27053',
#   'h_team': 'Atletico Madrid',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '1',
#   'date': '2024-09-29 19:00:00',
#   'player_assisted': 'Federico Valverde',
#   'lastAction': 'Pass'},
#  {'id': '595884',
#   'minute': '23',
#   'result': 'MissedShots',
#   'X': '0.765',
#   'Y': '0.745',
#   'xG': '0.010147137567400932',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'SetPiece',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '27063',
#   'h_team': 'Real Madrid',
#   'a_team': 'Villarreal',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2024-10-05 19:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '595893',
#   'minute': '69',
#   'result': 'MissedShots',
#   'X': '0.8769999694824219',
#   'Y': '0.7',
#   'xG': '0.054297883063554764',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '27063',
#   'h_team': 'Real Madrid',
#   'a_team': 'Villarreal',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2024-10-05 19:00:00',
#   'player_assisted': 'Kylian Mbappe-Lottin',
#   'lastAction': 'Pass'},
#  {'id': '595894',
#   'minute': '72',
#   'result': 'Goal',
#   'X': '0.7480000305175781',
#   'Y': '0.4490000152587891',
#   'xG': '0.029266515746712685',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '27063',
#   'h_team': 'Real Madrid',
#   'a_team': 'Villarreal',
#   'h_goals': '2',
#   'a_goals': '0',
#   'date': '2024-10-05 19:00:00',
#   'player_assisted': 'Federico Valverde',
#   'lastAction': 'Pass'},
#  {'id': '597396',
#   'minute': '16',
#   'result': 'MissedShots',
#   'X': '0.750999984741211',
#   'Y': '0.605999984741211',
#   'xG': '0.02083434723317623',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '27075',
#   'h_team': 'Celta Vigo',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2024-10-19 19:00:00',
#   'player_assisted': 'Jude Bellingham',
#   'lastAction': 'Pass'},
#  {'id': '597400',
#   'minute': '38',
#   'result': 'MissedShots',
#   'X': '0.9180000305175782',
#   'Y': '0.49599998474121093',
#   'xG': '0.45355862379074097',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'Head',
#   'match_id': '27075',
#   'h_team': 'Celta Vigo',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2024-10-19 19:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '597402',
#   'minute': '40',
#   'result': 'MissedShots',
#   'X': '0.9309999847412109',
#   'Y': '0.6680000305175782',
#   'xG': '0.08906752616167068',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'LeftFoot',
#   'match_id': '27075',
#   'h_team': 'Celta Vigo',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2024-10-19 19:00:00',
#   'player_assisted': 'Federico Valverde',
#   'lastAction': 'TakeOn'},
#  {'id': '597406',
#   'minute': '65',
#   'result': 'Goal',
#   'X': '0.925',
#   'Y': '0.3659999847412109',
#   'xG': '0.3638724088668823',
#   'player': 'Vinícius Júnior',
#   'h_a': 'a',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '27075',
#   'h_team': 'Celta Vigo',
#   'a_team': 'Real Madrid',
#   'h_goals': '1',
#   'a_goals': '2',
#   'date': '2024-10-19 19:00:00',
#   'player_assisted': 'Luka Modric',
#   'lastAction': 'Throughball'},
#  {'id': '598703',
#   'minute': '21',
#   'result': 'MissedShots',
#   'X': '0.9080000305175782',
#   'Y': '0.63',
#   'xG': '0.30438435077667236',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '27085',
#   'h_team': 'Real Madrid',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '4',
#   'date': '2024-10-26 19:00:00',
#   'player_assisted': 'Aurelien Tchouameni',
#   'lastAction': 'TakeOn'},
#  {'id': '598709',
#   'minute': '51',
#   'result': 'BlockedShot',
#   'X': '0.8640000152587891',
#   'Y': '0.720999984741211',
#   'xG': '0.03510928153991699',
#   'player': 'Vinícius Júnior',
#   'h_a': 'h',
#   'player_id': '7008',
#   'situation': 'OpenPlay',
#   'season': '2024',
#   'shotType': 'RightFoot',
#   'match_id': '27085',
#   'h_team': 'Real Madrid',
#   'a_team': 'Barcelona',
#   'h_goals': '0',
#   'a_goals': '4',
#   'date': '2024-10-26 19:00:00',
#   'player_assisted': None,
#   'lastAction': 'None'}]

# %%
df = pd.DataFrame(data) #dataframe

# %%
df
# Out:
#          id minute       result                   X                    Y  \
# 0    258765     82         Goal               0.885   0.6880000305175781
# 1    259285     89  MissedShots  0.7930000305175782    0.674000015258789
# 2    260090     86  BlockedShot   0.924000015258789  0.27600000381469725
# 3    279985     14    SavedShot  0.8930000305175781   0.6630000305175782
# 4    279997     46    SavedShot  0.9619999694824218  0.37099998474121093
# ..      ...    ...          ...                 ...                  ...
# 381  597400     38  MissedShots  0.9180000305175782  0.49599998474121093
# 382  597402     40  MissedShots  0.9309999847412109   0.6680000305175782
# 383  597406     65         Goal               0.925   0.3659999847412109
# 384  598703     21  MissedShots  0.9080000305175782                 0.63
# 385  598709     51  BlockedShot  0.8640000152587891    0.720999984741211
#
#                        xG           player h_a player_id   situation season  \
# 0    0.051118601113557816  Vinícius Júnior   h      7008    OpenPlay   2018
# 1     0.02699729986488819  Vinícius Júnior   a      7008    OpenPlay   2018
# 2    0.052585601806640625  Vinícius Júnior   h      7008    OpenPlay   2018
# 3     0.22689999639987946  Vinícius Júnior   h      7008    OpenPlay   2018
# 4     0.08477749675512314  Vinícius Júnior   h      7008  FromCorner   2018
# ..                    ...              ...  ..       ...         ...    ...
# 381   0.45355862379074097  Vinícius Júnior   a      7008    OpenPlay   2024
# 382   0.08906752616167068  Vinícius Júnior   a      7008    OpenPlay   2024
# 383    0.3638724088668823  Vinícius Júnior   a      7008    OpenPlay   2024
# 384   0.30438435077667236  Vinícius Júnior   h      7008    OpenPlay   2024
# 385   0.03510928153991699  Vinícius Júnior   h      7008    OpenPlay   2024
#
#       shotType match_id       h_team           a_team h_goals a_goals  \
# 0    RightFoot    10065  Real Madrid  Real Valladolid       2       0
# 1    RightFoot    10084        Eibar      Real Madrid       3       0
# 2    RightFoot    10116  Real Madrid   Rayo Vallecano       1       0
# 3     LeftFoot    10133  Real Madrid    Real Sociedad       0       2
# 4    RightFoot    10133  Real Madrid    Real Sociedad       0       2
# ..         ...      ...          ...              ...     ...     ...
# 381       Head    27075   Celta Vigo      Real Madrid       1       2
# 382   LeftFoot    27075   Celta Vigo      Real Madrid       1       2
# 383  RightFoot    27075   Celta Vigo      Real Madrid       1       2
# 384  RightFoot    27085  Real Madrid        Barcelona       0       4
# 385  RightFoot    27085  Real Madrid        Barcelona       0       4
#
#                     date      player_assisted    lastAction
# 0    2018-11-03 15:15:00                 Isco          Pass
# 1    2018-11-24 12:00:00              Marcelo  BallRecovery
# 2    2018-12-15 17:30:00        Lucas Vázquez          Pass
# 3    2019-01-06 17:30:00        Karim Benzema          Pass
# 4    2019-01-06 17:30:00                 None       Rebound
# ..                   ...                  ...           ...
# 381  2024-10-19 19:00:00                 None          None
# 382  2024-10-19 19:00:00    Federico Valverde        TakeOn
# 383  2024-10-19 19:00:00          Luka Modric   Throughball
# 384  2024-10-26 19:00:00  Aurelien Tchouameni        TakeOn
# 385  2024-10-26 19:00:00                 None          None
#
# [386 rows x 20 columns]

# %%
df['id'] = pd.to_numeric(df['id'], errors='coerce')
df['minute'] = pd.to_numeric(df['minute'], errors='coerce')
df['result'] = df['result'].astype(str)
#problem with X and Y
df['xG'] = pd.to_numeric(df['xG'], errors='coerce')
df['player'] = df['player'].astype(str)
df['h_a'] = df['h_a'].astype(str)
df['player_id'] = pd.to_numeric(df['player_id'], errors='coerce')
df['situation'] = df['situation'].astype(str)
df['season'] = pd.to_numeric(df['season'], errors='coerce')
df['shotType'] = df['shotType'].astype(str)
df['match_id'] = pd.to_numeric(df['match_id'], errors='coerce')
df['h_team'] = df['h_team'].astype(str)
df['a_team'] = df['a_team'].astype(str)
df['h_goals'] = pd.to_numeric(df['h_goals'], errors='coerce')
df['a_goals'] = pd.to_numeric(df['a_goals'], errors='coerce')
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df['player_assisted'] = df['player_assisted'].astype(str)
df['lastAction'] = df['lastAction'].astype(str)

# %%
df.head()
# Out:
#        id  minute       result                   X                    Y  \
# 0  258765      82         Goal               0.885   0.6880000305175781
# 1  259285      89  MissedShots  0.7930000305175782    0.674000015258789
# 2  260090      86  BlockedShot   0.924000015258789  0.27600000381469725
# 3  279985      14    SavedShot  0.8930000305175781   0.6630000305175782
# 4  279997      46    SavedShot  0.9619999694824218  0.37099998474121093
#
#          xG           player h_a  player_id   situation  season   shotType  \
# 0  0.051119  Vinícius Júnior   h       7008    OpenPlay    2018  RightFoot
# 1  0.026997  Vinícius Júnior   a       7008    OpenPlay    2018  RightFoot
# 2  0.052586  Vinícius Júnior   h       7008    OpenPlay    2018  RightFoot
# 3  0.226900  Vinícius Júnior   h       7008    OpenPlay    2018   LeftFoot
# 4  0.084777  Vinícius Júnior   h       7008  FromCorner    2018  RightFoot
#
#    match_id       h_team           a_team  h_goals  a_goals  \
# 0     10065  Real Madrid  Real Valladolid        2        0
# 1     10084        Eibar      Real Madrid        3        0
# 2     10116  Real Madrid   Rayo Vallecano        1        0
# 3     10133  Real Madrid    Real Sociedad        0        2
# 4     10133  Real Madrid    Real Sociedad        0        2
#
#                  date player_assisted    lastAction
# 0 2018-11-03 15:15:00            Isco          Pass
# 1 2018-11-24 12:00:00         Marcelo  BallRecovery
# 2 2018-12-15 17:30:00   Lucas Vázquez          Pass
# 3 2019-01-06 17:30:00   Karim Benzema          Pass
# 4 2019-01-06 17:30:00            None       Rebound

# %%
# Remove any extra spaces or non-numeric characters before conversion
df['X'] = df['X'].str.strip()
df['Y'] = df['Y'].str.strip()

# Convert to numeric
df['X'] = pd.to_numeric(df['X'], errors='coerce')
df['Y'] = pd.to_numeric(df['Y'], errors='coerce')

# Verify if there are still NaNs
print(df[['X', 'Y']].head())
print(df.dtypes)
# Out:
#        X      Y
# 0  0.885  0.688
# 1  0.793  0.674
# 2  0.924  0.276
# 3  0.893  0.663
# 4  0.962  0.371
# id                          int64
# minute                      int64
# result                     object
# X                         float64
# Y                         float64
# xG                        float64
# player                     object
# h_a                        object
# player_id                   int64
# situation                  object
# season                      int64
# shotType                   object
# match_id                    int64
# h_team                     object
# a_team                     object
# h_goals                     int64
# a_goals                     int64
# date               datetime64[ns]
# player_assisted            object
# lastAction                 object
# dtype: object

# %%
df.head()
# Out:
#        id  minute       result      X      Y        xG           player h_a  \
# 0  258765      82         Goal  0.885  0.688  0.051119  Vinícius Júnior   h
# 1  259285      89  MissedShots  0.793  0.674  0.026997  Vinícius Júnior   a
# 2  260090      86  BlockedShot  0.924  0.276  0.052586  Vinícius Júnior   h
# 3  279985      14    SavedShot  0.893  0.663  0.226900  Vinícius Júnior   h
# 4  279997      46    SavedShot  0.962  0.371  0.084777  Vinícius Júnior   h
#
#    player_id   situation  season   shotType  match_id       h_team  \
# 0       7008    OpenPlay    2018  RightFoot     10065  Real Madrid
# 1       7008    OpenPlay    2018  RightFoot     10084        Eibar
# 2       7008    OpenPlay    2018  RightFoot     10116  Real Madrid
# 3       7008    OpenPlay    2018   LeftFoot     10133  Real Madrid
# 4       7008  FromCorner    2018  RightFoot     10133  Real Madrid
#
#             a_team  h_goals  a_goals                date player_assisted  \
# 0  Real Valladolid        2        0 2018-11-03 15:15:00            Isco
# 1      Real Madrid        3        0 2018-11-24 12:00:00         Marcelo
# 2   Rayo Vallecano        1        0 2018-12-15 17:30:00   Lucas Vázquez
# 3    Real Sociedad        0        2 2019-01-06 17:30:00   Karim Benzema
# 4    Real Sociedad        0        2 2019-01-06 17:30:00            None
#
#      lastAction
# 0          Pass
# 1  BallRecovery
# 2          Pass
# 3          Pass
# 4       Rebound

# %%
df['X']=df['X']*100
df['Y']=df['Y']*100

# %%
df.head()
# Out:
#        id  minute       result          X          Y        xG  \
# 0  258765      82         Goal  88.500000  68.800003  0.051119
# 1  259285      89  MissedShots  79.300003  67.400002  0.026997
# 2  260090      86  BlockedShot  92.400002  27.600000  0.052586
# 3  279985      14    SavedShot  89.300003  66.300003  0.226900
# 4  279997      46    SavedShot  96.199997  37.099998  0.084777
#
#             player h_a  player_id   situation  season   shotType  match_id  \
# 0  Vinícius Júnior   h       7008    OpenPlay    2018  RightFoot     10065
# 1  Vinícius Júnior   a       7008    OpenPlay    2018  RightFoot     10084
# 2  Vinícius Júnior   h       7008    OpenPlay    2018  RightFoot     10116
# 3  Vinícius Júnior   h       7008    OpenPlay    2018   LeftFoot     10133
# 4  Vinícius Júnior   h       7008  FromCorner    2018  RightFoot     10133
#
#         h_team           a_team  h_goals  a_goals                date  \
# 0  Real Madrid  Real Valladolid        2        0 2018-11-03 15:15:00
# 1        Eibar      Real Madrid        3        0 2018-11-24 12:00:00
# 2  Real Madrid   Rayo Vallecano        1        0 2018-12-15 17:30:00
# 3  Real Madrid    Real Sociedad        0        2 2019-01-06 17:30:00
# 4  Real Madrid    Real Sociedad        0        2 2019-01-06 17:30:00
#
#   player_assisted    lastAction
# 0            Isco          Pass
# 1         Marcelo  BallRecovery
# 2   Lucas Vázquez          Pass
# 3   Karim Benzema          Pass
# 4            None       Rebound

# %%
total_shots = df.shape[0] 
total_goals = df[df['result']=='Goal'].shape[0]
total_xG = df['xG'].sum()
xG_per_shot = total_xG/total_shots
points_average_distance = df['X'].mean()
actual_average_distance = 120-(df['X']*1.2).mean()

# %%
actual_average_distance
# Out:
# np.float64(15.058445848455094)

# %%
# Color -> They went with a black so we'll do the same. Notice how it isn't a pure black but rather a lighter little bit of grey black
background_color='#0C0D0E'

# Font -> Fonts are tricky since they have their "brand fonts" so we'll just use something similar
import matplotlib.font_manager as font_manager
font_path = '/home/shukra/dev/football-analysis/Fonts/EBGaramond08-Regular.otf'
# Create a font properties object with the font file
font_props = font_manager.FontProperties(fname=font_path)

# %%
pitch = VerticalPitch(
    pitch_type='opta', 
    half=True, 
    pitch_color=background_color, 
    pad_bottom=.5, 
    line_color='white',
    linewidth=.75,
    axis=True, label=True
)

# %%
# create a subplot with 2 rows and 1 column
fig = plt.figure(figsize=(8, 12))
fig.patch.set_facecolor(background_color)

# %%
# Top row for the team names and score
# [left, bottom, width, height]

ax1 = fig.add_axes([0, 0.7, 1, .2])
ax1.set_facecolor(background_color)
ax1.set_xlim(0, 1)
ax1.set_ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
ax1.text(
    x=0.5, 
    y=.85, 
    s='Erling Haaland', 
    fontsize=20, 
    fontproperties=font_props, 
    fontweight='bold', 
    color='white', 
    ha='center'
)
ax1.text(
    x=0.5, 
    y=.7, 
    s=f'All shots in the Premier League 2022-23', 
    fontsize=14,
    fontweight='bold',
    fontproperties=font_props, 
    color='white', 
    ha='center'
)
ax1.text(
    x=0.25, 
    y=0.5, 
    s=f'Low Quality Chance', 
    fontsize=12, 
    fontproperties=font_props, 
    color='white', 
    ha='center'
)

# add a scatter point between the two texts
ax1.scatter(
    x=0.37, 
    y=0.53, 
    s=100, 
    color=background_color, 
    edgecolor='white', 
    linewidth=.8
)
ax1.scatter(
    x=0.42, 
    y=0.53, 
    s=200, 
    color=background_color, 
    edgecolor='white', 
    linewidth=.8
)
ax1.scatter(
    x=0.48, 
    y=0.53, 
    s=300, 
    color=background_color, 
    edgecolor='white', 
    linewidth=.8
)
ax1.scatter(
    x=0.54, 
    y=0.53, 
    s=400, 
    color=background_color, 
    edgecolor='white', 
    linewidth=.8
)
ax1.scatter(
    x=0.6, 
    y=0.53, 
    s=500, 
    color=background_color, 
    edgecolor='white', 
    linewidth=.8
)

ax1.text(
    x=0.75, 
    y=0.5, 
    s=f'High Quality Chance', 
    fontsize=12, 
    fontproperties=font_props, 
    color='white', 
    ha='center'
)


ax1.text(
    x=0.45, 
    y=0.27, 
    s=f'Goal', 
    fontsize=10, 
    fontproperties=font_props, 
    color='white', 
    ha='right'
)
ax1.scatter(
    x=0.47, 
    y=0.3, 
    s=100, 
    color='red', 
    edgecolor='white', 
    linewidth=.8,
    alpha=.7
)


ax1.scatter(
    x=0.53, 
    y=0.3, 
    s=100, 
    color=background_color, 
    edgecolor='white', 
    linewidth=.8
)

ax1.text(
    x=0.55, 
    y=0.27, 
    s=f'No Goal', 
    fontsize=10, 
    fontproperties=font_props, 
    color='white', 
    ha='left'
)

ax1.set_axis_off()


ax2 = fig.add_axes([.05, 0.25, .9, .5])
ax2.set_facecolor(background_color)

pitch.draw(ax=ax2)


# create a scatter plot at y 100 - average_distance
ax2.scatter(
    x=90, 
    y=points_average_distance, 
    s=100, 
    color='white',  
    linewidth=.8
)
# create a line from the bottom of the pitch to the scatter point
ax2.plot(
    [90, 90], 
    [100, points_average_distance], 
    color='white', 
    linewidth=2
)

# Add a text label for the average distance
ax2.text(
    x=90, 
    y=points_average_distance - 4, 
    s=f'Average Distance\n{actual_average_distance:.1f} yards', 
    fontsize=10, 
    fontproperties=font_props, 
    color='white', 
    ha='center'
)


for x in df.to_dict(orient='records'):
    pitch.scatter(
        x['X'], 
        x['Y'], 
        s=300 * x['xG'], 
        color='red' if x['result'] == 'Goal' else background_color, 
        ax=ax2,
        alpha=.7,
        linewidth=.8,
        edgecolor='white'
    )
    
ax2.set_axis_off()

# add another axis for the stats
ax3 = fig.add_axes([0, .2, 1, .05])
ax3.set_facecolor(background_color)
ax3.set_xlim(0, 1)
ax3.set_ylim(0, 1)

ax3.text(
    x=0.25, 
    y=.5, 
    s='Shots', 
    fontsize=20, 
    fontproperties=font_props, 
    fontweight='bold', 
    color='white', 
    ha='left'
)

ax3.text(
    x=0.25, 
    y=0, 
    s=f'{total_shots}', 
    fontsize=16, 
    fontproperties=font_props, 
    color='red', 
    ha='left'
)

ax3.text(
    x=0.38, 
    y=.5, 
    s='Goals', 
    fontsize=20, 
    fontproperties=font_props, 
    fontweight='bold', 
    color='white', 
    ha='left'
)

ax3.text(
    x=0.38, 
    y=0, 
    s=f'{total_goals}', 
    fontsize=16, 
    fontproperties=font_props, 
    color='red', 
    ha='left'
)

ax3.text(
    x=0.53, 
    y=.5, 
    s='xG', 
    fontsize=20, 
    fontproperties=font_props, 
    fontweight='bold', 
    color='white', 
    ha='left'
)

ax3.text(
    x=0.53, 
    y=0, 
    s=f'{total_xG:.2f}', 
    fontsize=16, 
    fontproperties=font_props, 
    color='red', 
    ha='left'
)

ax3.text(
    x=0.63, 
    y=.5, 
    s='xG/Shot', 
    fontsize=20, 
    fontproperties=font_props, 
    fontweight='bold', 
    color='white', 
    ha='left'
)

ax3.text(
    x=0.63, 
    y=0, 
    s=f'{xG_per_shot:.2f}', 
    fontsize=16, 
    fontproperties=font_props, 
    color='red', 
    ha='left'
)

ax3.set_axis_off()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 215
#     191 ax3.text(
#     192     x=0.25,
#     193     y=0,
#    (...)
#     198     ha='left'
#     199 )
#     201 ax3.text(
#     202     x=0.38,
#     203     y=.5,
#    (...)
#     209     ha='left'
#     210 )
#     212 ax3.text(
#     213     x=0.38,
#     214     y=0,
# --> 215     s=f'{total_goals}',
#     216     fontsize=16,
#     217     fontproperties=font_props,
#     218     color='red',
#     219     ha='left'
#     220 )
#     222 ax3.text(
#     223     x=0.53,
#     224     y=.5,
#    (...)
#     230     ha='left'
#     231 )
#     233 ax3.text(
#     234     x=0.53,
#     235     y=0,
#    (...)
#     240     ha='left'
#     241 )
#
# NameError: name 'total_goals' is not defined
